# %%
import pulp

# 111
y1 = pulp.LpVariable("y1", lowBound=0, upBound=2000)
z1 = pulp.LpVariable("z1", lowBound=0, upBound=2000)
# 112
y2 = pulp.LpVariable("y2", lowBound=0, upBound=2000)
z2 = pulp.LpVariable("z2", lowBound=0, upBound=2000)
# 113
y3 = pulp.LpVariable("y3", lowBound=0, upBound=2000)
z3 = pulp.LpVariable("z3", lowBound=0, upBound=2000)

######################################

# 121
y4 = pulp.LpVariable("y4", lowBound=0, upBound=2000)
z4 = pulp.LpVariable("z4", lowBound=0, upBound=2000)
# 122
y5 = pulp.LpVariable("y5", lowBound=0, upBound=2000)
z5 = pulp.LpVariable("z5", lowBound=0, upBound=2000)
# 123
y6 = pulp.LpVariable("y6", lowBound=0, upBound=2000)
z6 = pulp.LpVariable("z6", lowBound=0, upBound=2000)


######################################

# 131
y7 = pulp.LpVariable("y7", lowBound=0, upBound=2000)
z7 = pulp.LpVariable("z7", lowBound=0, upBound=2000)
# 132
y8 = pulp.LpVariable("y8", lowBound=0, upBound=2000)
z8 = pulp.LpVariable("z8", lowBound=0, upBound=2000)
# 133
y9 = pulp.LpVariable("y9", lowBound=0, upBound=2000)
z9 = pulp.LpVariable("z9", lowBound=0, upBound=2000)

######################################

# 211
y10 = pulp.LpVariable("y10", lowBound=0, upBound=2000)
z10 = pulp.LpVariable("z10", lowBound=0, upBound=2000)
# 212
y11 = pulp.LpVariable("y11", lowBound=0, upBound=2000)
z11 = pulp.LpVariable("z11", lowBound=0, upBound=2000)
# 213
y12 = pulp.LpVariable("y12", lowBound=0, upBound=2000)
z12 = pulp.LpVariable("z12", lowBound=0, upBound=2000)

######################################

# 221
y13 = pulp.LpVariable("y13", lowBound=0, upBound=2000)
z13 = pulp.LpVariable("z13", lowBound=0, upBound=2000)
# 222
y14 = pulp.LpVariable("y14", lowBound=0, upBound=2000)
z14 = pulp.LpVariable("z14", lowBound=0, upBound=2000)
# 223
y15 = pulp.LpVariable("y15", lowBound=0, upBound=2000)
z15 = pulp.LpVariable("z15", lowBound=0, upBound=2000)

######################################

# 231
y16 = pulp.LpVariable("y16", lowBound=0, upBound=2000)
z16 = pulp.LpVariable("z16", lowBound=0, upBound=2000)
# 232
y17 = pulp.LpVariable("y17", lowBound=0, upBound=2000)
z17 = pulp.LpVariable("z17", lowBound=0, upBound=2000)
# 233
y18 = pulp.LpVariable("y18", lowBound=0, upBound=2000)
z18 = pulp.LpVariable("z18", lowBound=0, upBound=2000)

problem = pulp.LpProblem('0', pulp.LpMaximize)

## суммарная масса - стоимость присадки, не учтена поправка на используемую энергию
problem += (1.1 * 126 - .1 * 210) * (y1 + y2 + y3 + y4 + y5 + y6 + y7 + y8 + y9) \
+ (1.05 * 125 - .05 * 120) * (z1 + z2 + z3 + z4 + z5 + z6 + z7 + z8 + z9) \
+ (1.12 * 116 - .12 * 200) * (y10 + y11 + y12 + y13 + y14 + y15 + y16 + y17 + y18) \
+ (1.07 * 115 - .07 * 110) * (z10 + z11 + z12 + z13 + z14 + z15 + z16 + z17 + z18), "функция цели"

## условие на количество топлива
problem += (y1 + z1) + (y2 + z2) + (y3 + z3) \
+ (y4 + z4) + (y5 + z5) + (y6 + z6) \
+ (y7 + z7) + (y8 + z8) + (y9 + z9) \
+ (y10 + z10) + (y11 + z11) + (y12 + z12) \
+ (y13 + z13) + (y14 + z14) + (y15 + z15) \
+ (y16 + z16) + (y17 + z17) + (y18 + z18) == 2000

# условия на режимы
problem += (y1 + z1)*100 == 15 * (y1 + z1 + y2 + z2 + y3 + z3)
problem += (y2 + z2)*100 == 25 * (y1 + z1 + y2 + z2 + y3 + z3)
# problem += (y3 + z3)*100 == 60 * (y1 + z1 + y2 + z2 + y3 + z3)

problem += (y4 + z4)*100 == 20 * (y4 + z4 + y5 + z5 + y6 + z6)
problem += (y5 + z5)*100 == 30 * (y4 + z4 + y5 + z5 + y6 + z6)
# problem += (y6 + z6)*100 == 50 * (y4 + z4 + y5 + z5 + y6 + z6)

problem += (y7 + z7)*100 == 20 * (y7 + z7 + y8 + z8 + y9 + z9)
problem += (y8 + z8)*100 == 30 * (y7 + z7 + y8 + z8 + y9 + z9)
# problem += (y9 + z9)*100 == 50 * (y7 + z7 + y8 + z8 + y9 + z9)

problem += (y10 + z10)*100 == 25 * (y10 + z10 + y11 + z11 + y12 + z12)
problem += (y11 + z11)*100 == 35 * (y10 + z10 + y11 + z11 + y12 + z12)
#problem += (y12 + z12)*100 == 40 * (y10 + z10 + y11 + z11 + y12 + z12)

problem += (y13 + z13)*100 == 35 * (y13 + z13 + y14 + z14 + y15 + z15)
problem += (y14 + z14)*100 == 20 * (y13 + z13 + y14 + z14 + y15 + z15)
# problem += (y15 + z15)*100 == 45 * (y13 + z13 + y14 + z14 + y15 + z15)

problem += (y16 + z16)*100 == 35 * (y16 + z16 + y17 + z17 + y18 + z18)
problem += (y17 + z17)*100 == 35 * (y16 + z16 + y17 + z17 + y18 + z18)
problem += (y18 + z18)*100 == 30 * (y16 + z16 + y17 + z17 + y18 + z18)

## условия на присадки
problem += y1 + y2 + y3 + y4 + y5 + y6 + y7 + y8 + y9 - 900 <= 0
problem += 400 - (y1 + y2 + y3 + y4 + y5 + y6 + y7 + y8 + y9) <= 0
problem += z1 + z2 + z3 + z4 + z5 + z6 + z7 + z8 + z9 - 900 <= 0
problem += 400 - (z1 + z2 + z3 + z4 + z5 + z6 + z7 + z8 + z9) <= 0

problem += y10 + y11 + y12 + y13 + y14 + y15 + y16 + y17 + y18 - 1000 <= 0
problem += 500 - (y10 + y11 + y12 + y13 + y14 + y15 + y16 + y17 + y18) <= 0
problem += z10 + z11 + z12 + z13 + z14 + z15 + z16 + z17 + z18 - 1000 <= 0
problem += 500 - (z10 + z11 + z12 + z13 + z14 + z15 + z16 + z17 + z18) <= 0

## условие на плотность            
problem += y1 + y2 + y3 + y4 + y5 + y6 + y7 + y8 + y9 - .9 * (y1 * 1/.62  + y2 * 1/.7 + y3 * 1/.79 + y4 * 1/.78 + y5 * 1 /.8 + y6 * 1 /.82 + y7 * 1/.8 + y8 * 1 /.95 + y9 * 1/1.15) <= 0
problem += .82 * (y1 * 1/.62  + y2 * 1/.7 + y3 * 1/.79 + y4 * 1/.78 + y5 * 1/.8 + y6 * 1/.82 + y7 * 1/.8 + y8 * 1/.95 + y9 * 1/1.15) - (y1 + y2 + y3 + y4 + y5 + y6 + y7 + y8 + y9) <= 0 

problem += z1 + z2 + z3 + z4 + z5 + z6 + z7 + z8 + z9 - .99 * (z1 * 1/.62  + z2 * 1/.7 + z3 * 1/.79 + z4 * 1/.78 + z5 * 1/.8 + z6 * 1/.82 + z7 * 1/.8 + z8 * 1/.95 + z9 * 1/1.15) <= 0
problem += .79 * (z1 * 1/.62  + z2 * 1/.7 + z3 * 1/.79 + z4 * 1/.78 + z5 * 1/.8 + z6 * 1/.82 + z7 * 1/.8 + z8 * 1/.95 + z9 * 1/1.15) - (z1 + z2 + z3 + z4 + z5 + z6 + z7 + z8 + z9) <= 0

problem += y10 + y11 + y12 + y13 + y14 + y15 + y16 + y17 + y18 - .9 * (y10 * 1/.8  + y11 * 1/.95 + y12 * 1/1.2 + y13 * 1/.8 + y14 * 1/.9 + y15 * 1/1.3 + y16 * 1/.69 + y17 * 1/.82 + y18 * 1/.93) <= 0
problem += .82 * (y10 * 1/.8  + y11 * 1/.95 + y12 * 1/1.2 + y13 * 1/.8 + y14 * 1/.9 + y15 * 1/1.3 + y16 * 1/.69 + y17 * 1/.82 + y18 * 1/.93) - (y10 + y11 + y12 + y13 + y14 + y15 + y16 + y17 + y18) >= 0

problem += z10 + z11 + z12 + z13 + z14 + z15 + z16 + z17 + z18 - .99 * (z10 * 1/.8  + z11 * 1/.95 + z12 * 1/1.2 + z13 * 1/.8 + z14 * 1/.9 + z15 * 1/1.3 + z16 * 1/.69 + z17 * 1/.82 + z18 * 1/.93) <= 0
problem += .79 * (z10 * 1/.8  + z11 * 1/.95 + z12 * 1/1.2 + z13 * 1/.8 + z14 * 1/.9 + z15 * 1/1.3 + z16 * 1/.69 + z17 * 1/.82 + z18 * 1/.93) - (z10 + z11 + z12 + z13 + z14 + z15 + z16 + z17 + z18) <= 0

## условие на серу
problem += y1*.2 + y2*.3 + y3*.4 + y4*1.1 + y5*1.35 + y6*1.86 + y7*.002 + y8*.0023 + y9*.0035 - 1.1*(y1 + y2 + y3 + y4 + y5 + y6 + y7 + y8 + y9) <= 0
problem += .6*(y1 + y2 + y3 + y4 + y5 + y6 + y7 + y8 + y9) - (y1*.2 + y2*.3 + y3*.4 + y4*1.1 + y5*1.35 + y6*1.86 + y7*.002 + y8*.0023 + y9*.0035) <= 0

problem += y10*.7 + y11*1.4 + y12*1.8 + y13*.6 + y14*1.11 + y15*1.5 + y16*.9 + y17*1.25 + y18*1.8 - 1.1*(y10 + y11 + y12 + y13 + y14 + y15 + y16 + y17 + y18) <= 0
problem += .6*(y10 + y11 + y12 + y13 + y14 + y15 + y16 + y17 + y18) - (y10*.7 + y11*1.4 + y12*1.8 + y13*.6 + y14*1.11 + y15*1.5 + y16*.9 + y17*1.25 + y18*1.8) <= 0

problem += z1*.2 + z2*.3 + z3*.4 + z4*1.1 + z5*1.35 + z6*1.86 + z7*.002 + z8*.0023 + z9*.0035 - .9*(z1 + z2 + z3 + z4 + z5 + z6 + z7 + z8 + z9) <= 0
problem += .5*(z1 + z2 + z3 + z4 + z5 + z6 + z7 + z8 + z9) - (z1*.2 + z2*.3 + z3*.4 + z4*1.1 + z5*1.35 + z6*1.86 + z7*.002 + z8*.0023 + z9*.0035) <= 0

#problem += z10*.7 + z11*1.4 + z12*1.8 + z13*.6 + z14*1.11 + z15*1.5 + z16*.9 + z17*1.25 + z18*1.8 - .9*(z10 + z11 + z12 + z13 + z14 + z15 + z16 + z17 + z18) <= 0
#problem += z10*.7 + z11*1.4 + z12*1.8 + z13*.6 + z14*1.11 + z15*1.5 + z16*.9 + z17*1.25 + z18*1.8 >= .5*(z10 + z11 + z12 + z13 + z14 + z15 + z16 + z17 + z18)

## условие на k фактор
problem += 50*y1 + 40*y2 + 30*y3 + 104*y4 + 107*y5 + 100*y6 + 105*y7 + 86*y8 + 104*y9 <= 55*(y1 + y2 + y3 + y4 + y5 + y6 + y7 + y8 + y9)  
problem += 50*y1 + 40*y2 + 30*y3 + 104*y4 + 107*y5 + 100*y6 + 105*y7 + 86*y8 + 104*y9 >= 35*(y1 + y2 + y3 + y4 + y5 + y6 + y7 + y8 + y9)  
problem += 70*y10 + 63*y11 + 58*y12 + 71*y13 + 64*y14 + 65*y15 + 54*y16 + 61*y17 + 62*y18 <= 55*(y10 + y11 + y12 + y13 + y14 + y15 + y16 + y17 + y18)  
problem += 70*y10 + 63*y11 + 58*y12 + 71*y13 + 64*y14 + 65*y15 + 54*y16 + 61*y17 + 62*y18 >= 35*(y10 + y11 + y12 + y13 + y14 + y15 + y16 + y17 + y18)  

#problem += 50*z1 + 40*z2 + 30*z3 + 104*z4 + 107*z5 + 100*z6 + 105*z7 + 86*z8 + 104*z9 <= 62*(z1 + z2 + z3 + z4 + z5 + z6 + z7 + z8 + z9)  
#problem += 50*z1 + 40*z2 + 30*z3 + 104*z4 + 107*z5 + 100*z6 + 105*z7 + 86*z8 + 104*z9 >= 45*(z1 + z2 + z3 + z4 + z5 + z6 + z7 + z8 + z9)  
problem += 70*z10 + 63*z11 + 58*z12 + 71*z13 + 64*z14 + 65*z15 + 54*z16 + 61*z17 + 62*z18 <= 62*(z10 + z11 + z12 + z13 + z14 + z15 + z16 + z17 + z18)  
problem += 70*z10 + 63*z11 + 58*z12 + 71*z13 + 64*z14 + 65*z15 + 54*z16 + 61*z17 + 62*z18 >= 45*(z10 + z11 + z12 + z13 + z14 + z15 + z16 + z17 + z18)  



problem.solve()
print ("Результат:")
for variable in problem.variables():
    print (variable.name, "=", variable.varValue)
print ("Прибыль:")
print (value(problem.objective))
# Out:
# Результат:
# y1 = 0.0
# y10 = 0.0
# y11 = 0.0
# y12 = 0.0
# y13 = 0.0
# y14 = 0.0
# y15 = 0.0
# y16 = 428.57143
# y17 = 71.428571
# y18 = 0.0
# y2 = 13.660308
# y3 = 234.82497
# y4 = 0.0
# y5 = 0.0
# y6 = 82.69509
# y7 = 0.0
# y8 = 56.550668
# y9 = 12.268962
# z1 = 58.706243
# z10 = 0.0
# z11 = 0.0
# z12 = 0.0
# z13 = 0.0
# z14 = 0.0
# z15 = 0.0
# z16 = 0.0
# z17 = 357.14286
# z18 = 367.34694
# z2 = 84.18343
# z3 = 0.0
# z4 = 39.126605
# z5 = 58.689908
# z6 = 15.121422
# z7 = 37.700445
# z8 = 0.0
# z9 = 81.982151
# Прибыль:
# 230602.55135172003

# %%
def printVar(var, y_name, z_name):
    print("{}: топливо1: {} топливо2: {}".format(var, round(problem.variablesDict().get(y_name).varValue), round(problem.variablesDict().get(z_name).varValue)))
printVar("X111", "y1", "z1")
printVar("X112", "y2", "z2")
printVar("X113", "y3", "z3")
printVar("X121", "y4", "z4")
printVar("X122", "y5", "z5")
printVar("X123", "y6", "z6")
printVar("X131", "y7", "z7")
printVar("X132", "y8", "z8")
printVar("X133", "y9", "z9")
printVar("X211", "y10", "z10")
printVar("X212", "y11", "z11")
printVar("X213", "y12", "z12")
printVar("X221", "y13", "z13")
printVar("X222", "y14", "z14")
printVar("X223", "y15", "z15")
printVar("X231", "y16", "z16")
printVar("X232", "y17", "z17")
printVar("X233", "y18", "z18")
# Out:
# X111: топливо1: 0 топливо2: 59
# X112: топливо1: 14 топливо2: 84
# X113: топливо1: 235 топливо2: 0
# X121: топливо1: 0 топливо2: 39
# X122: топливо1: 0 топливо2: 59
# X123: топливо1: 83 топливо2: 15
# X131: топливо1: 0 топливо2: 38
# X132: топливо1: 57 топливо2: 0
# X133: топливо1: 12 топливо2: 82
# X211: топливо1: 0 топливо2: 0
# X212: топливо1: 0 топливо2: 0
# X213: топливо1: 0 топливо2: 0
# X221: топливо1: 0 топливо2: 0
# X222: топливо1: 0 топливо2: 0
# X223: топливо1: 0 топливо2: 0
# X231: топливо1: 429 топливо2: 0
# X232: топливо1: 71 топливо2: 357
# X233: топливо1: 0 топливо2: 367
